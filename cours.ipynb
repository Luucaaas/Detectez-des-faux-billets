# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ozone = pd.read_csv("Data_cours/Dataset_ozone.csv",delimiter=';')

# %%
ozone
# Out:
#      obs  maxO3    T9   T12   T15  Ne9  Ne12  Ne15      Vx9     Vx12     Vx15  \
# 0    601     87  15,6  18,5  18,4    4     4     8   0,6946  -1,7101  -0,6946
# 1    602     82    17  18,4  17,7    5     5     7  -4,3301       -4       -3
# 2    603     92  15,3  17,6  19,5    2     5     4   2,9544   1,8794   0,5209
# 3    604    114  16,2  19,7  22,5    1     1     0   0,9848   0,3473  -0,1736
# 4    605     94  17,4  20,5  20,4    8     8     7     -0,5  -2,9544  -4,3301
# ..   ...    ...   ...   ...   ...  ...   ...   ...      ...      ...      ...
# 107  925     84  13,3  17,7  17,8    3     5     6        0       -1  -1,2856
# 108  927     77  16,2  20,8  22,1    6     5     5  -0,6946       -2  -1,3681
# 109  928     99  16,9    23  22,6    6     4     7      1,5   0,8682   0,8682
# 110  929     83  16,9  19,8  22,1    6     5     3       -4  -3,7588       -4
# 111  930     70  15,7  18,6  20,7    7     7     7        0  -1,0419       -4
#
#      maxO3v   vent  pluie
# ...

# %%
plt.scatter(ozone["T12"], ozone["maxO3"], color='blue', marker='o', label='Data Points')

plt.xlabel('T12')
plt.ylabel('maxO3')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(ozone['T12'], ozone['maxO3'], color='black')

# Ajouter des étiquettes et un titre
plt.xlabel('T12', fontsize=14)
plt.ylabel('maxO3', fontsize=14)
plt.title('Scatter plot de T12 vs maxO3', fontsize=16)

# Ajouter une grille pour améliorer la lisibilité
plt.grid(True)

# Afficher le graphique
plt.show()

# %%
sns.set()

ax = sns.scatterplot(x="T12", y="maxO3", data=ozone)
ax.set(xlabel='T12', ylabel='MaxO3')
# Out:
# [Text(0.5, 0, 'T12'), Text(0, 0.5, 'MaxO3')]

# %%
arbre = pd.read_csv('Data_cours/les-arbres.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 arbre = pd.read_csv('Data_cours/les-arbres.csv')
#
# File ~/Desktop/OpenClassrooms/Projet 10/myenv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
